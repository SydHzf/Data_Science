# %%
import pandas as pd
import numpy as np

# %%
world_dev = pd.read_csv("World_dev.csv")

# %%
world_dev.columns
# Out:
# Index(['CountryCode', 'ShortName', 'TableName', 'LongName', 'Alpha2Code',
#        'CurrencyUnit', 'SpecialNotes', 'Region', 'IncomeGroup', 'Wb2Code',
#        'NationalAccountsBaseYear', 'NationalAccountsReferenceYear',
#        'SnaPriceValuation', 'LendingCategory', 'OtherGroups',
#        'SystemOfNationalAccounts', 'AlternativeConversionFactor',
#        'PppSurveyYear', 'BalanceOfPaymentsManualInUse',
#        'ExternalDebtReportingStatus', 'SystemOfTrade',
#        'GovernmentAccountingConcept', 'ImfDataDisseminationStandard',
#        'LatestPopulationCensus', 'LatestHouseholdSurvey',
#        'SourceOfMostRecentIncomeAndExpenditureData',
#        'VitalRegistrationComplete', 'LatestAgriculturalCensus',
#        'LatestIndustrialData', 'LatestTradeData', 'LatestWaterWithdrawalData'],
#       dtype='object')

# %%
pattern = r"national accounts"

# %%
search = world_dev['SpecialNotes'].str.contains(pattern)

# %%
world_dev[search == True]
# Out:
#     CountryCode            ShortName            TableName  \
# 0           AFG          Afghanistan          Afghanistan
# 5           AGO               Angola               Angola
# 6           ATG  Antigua and Barbuda  Antigua and Barbuda
# 11          AUS            Australia            Australia
# 15          BGD           Bangladesh           Bangladesh
# ..          ...                  ...                  ...
# 236         URY              Uruguay              Uruguay
# 238         VUT              Vanuatu              Vanuatu
# 240         VNM              Vietnam              Vietnam
# 244         YEM                Yemen          Yemen, Rep.
# 246         ZWE             Zimbabwe             Zimbabwe
#
#                             LongName Alpha2Code           CurrencyUnit  \
# 0       Islamic State of Afghanistan         AF         Afghan afghani
# 5        People's Republic of Angola         AO         Angolan kwanza
# ...

# %%
world_dev.loc[search == True,'SpecialNotes']
# Out:
# 0      Fiscal year end: March 20; reporting period fo...
# 5      April 2013 database update: Based on IMF data,...
# 6      April 2012 database update: Based on official ...
# 11     Fiscal year end: June 30; reporting period for...
# 15     Fiscal year end: June 30; reporting period for...
#                              ...
# 236    In 2011, the Central Bank revised national acc...
# 238    2013 national accounts estimates are based on ...
# 240    Based on data from the Vietnam Statistics Offi...
# 244    Based on official government statistics and In...
# 246    Fiscal year end: June 30; reporting period for...
# Name: SpecialNotes, Length: 70, dtype: object

# %%
pattern = r"[Nn]ational accounts"

search = world_dev['SpecialNotes'].str.contains(pattern)

world_dev.loc[search == True,'SpecialNotes']
# Out:
# 0      Fiscal year end: March 20; reporting period fo...
# 5      April 2013 database update: Based on IMF data,...
# 6      April 2012 database update: Based on official ...
# 11     Fiscal year end: June 30; reporting period for...
# 13     April 2012 database update: National accounts ...
#                              ...
# 238    2013 national accounts estimates are based on ...
# 240    Based on data from the Vietnam Statistics Offi...
# 244    Based on official government statistics and In...
# 245    The new base year is 2010. National accounts d...
# 246    Fiscal year end: June 30; reporting period for...
# Name: SpecialNotes, Length: 80, dtype: object

# %%
pd.options.display.max_columns = None

# %%
pd.options.display.max_rows = None

# %%
pattern = r"([Nn]ational accounts)"
# or r"([Nn]ational) (accounts)"
search = world_dev['SpecialNotes'].str.extract(pattern)
search
# Out:
#                      0
# 0    national accounts
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5    national accounts
# 6    national accounts
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11   national accounts
# 12                 NaN
# 13   National accounts
# 14                 NaN
# 15   national accounts
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25   national accounts
# 26                 NaN
# 27                 NaN
# 28   national accounts
# 29                 NaN
# 30                 NaN
# 31   national accounts
# 32                 NaN
# 33                 NaN
# 34   national accounts
# 35                 NaN
# 36                 NaN
# 37                 NaN
# 38                 NaN
# ...

# %%
pattern = r"([Nn]ational accounts)"
# or r"([Nn]ational) (accounts)"
search = world_dev['SpecialNotes'].str.extractall(pattern)
search
# Out:
#                            0
#     match
# 0   0      national accounts
#     1      National accounts
# 5   0      national accounts
# 6   0      national accounts
# 11  0      national accounts
# 13  0      National accounts
# 15  0      national accounts
# 25  0      national accounts
#     1      national accounts
# 28  0      national accounts
# 31  0      national accounts
# 34  0      national accounts
# 39  0      national accounts
# 42  0      national accounts
# 45  0      national accounts
# 57  0      national accounts
# 61  0      National accounts
# 62  0      national accounts
# 64  0      National accounts
# 65  0      national accounts
# 67  0      national accounts
#     1      national accounts
# 73  0      national accounts
# 81  0      national accounts
# 84  0      national accounts
# 88  0      national accounts
# 90  0      national accounts
#     1      national accounts
# 97  0      national accounts
# 99  0      national accounts
# ...

# %%
pattern = r"(?P<Year>[1-2][0-9]{3})"

# %%
search = world_dev['SpecialNotes'].str.extractall(pattern)
search
# Out:
#            Year
#     match
# 0   0      2013
# 5   0      2013
#     1      2000
#     2      2002
# 6   0      2012
#     1      2000
#     2      2006
# 8   0      2004
# 10  0      2000
#     1      2011
#     2      1994
#     3      1999
#     4      1995
#     5      2000
# 11  0      1990
#     1      2008
# 12  0      1999
#     1      1999
# 13  0      2012
# 14  0      2010
# 15  0      2005
# 18  0      1999
#     1      1999
# 22  0      2013
# 24  0      2010
# 25  0      2006
#     1      2006
#     2      2006
# 28  0      2010
#     1      2011
#     2      1995
# 31  0      1990
#     1      2007
# 39  0      2005
#     1      2005
# 42  0      1997
#     1      1999
#     2      2000
# 45  0      2013
#     1      1990
#     2      1990
# 47  0      2009
# 48  0      2010
#     1      2013
#     2      2005
# 51  0      2008
# 54  0      2005
# 57  0      2012
#     1      2000
#     2      2006
# 61  0      1965
#     1      2007
# 62  0      2001
# ...
