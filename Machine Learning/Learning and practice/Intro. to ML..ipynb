# %%
import pandas as pd 
import numpy as np
import datetime as dt

# %%
dataset = pd.read_csv("dc_airbnb.csv")

# %%
dataset
# Out:
#      host_response_rate host_acceptance_rate  host_listings_count  \
# 0                   92%                  91%                   26
# 1                   90%                 100%                    1
# 2                   90%                 100%                    2
# 3                  100%                  NaN                    1
# 4                   92%                  67%                    1
# ...                 ...                  ...                  ...
# 3718               100%                  60%                    1
# 3719               100%                  50%                    1
# 3720               100%                 100%                    2
# 3721                88%                 100%                    1
# 3722                70%                 100%                    1
#
#       accommodates        room_type  bedrooms  bathrooms  beds    price  \
# 0                4  Entire home/apt       1.0        1.0   2.0  $160.00
# ...

# %% [markdown]
# # rules data sy ly raha hai jk experience hai
# # Algo mai koi relation nhi hota similarity check krtry hain.(muslun kuch beechna hai to usko duniya k dosry cheezo sy compare krty hoy price guess kryngy.)
# # Model relation pr kaam krta hai ind and dep k drmiyan (muslun effect of cloud on wheather)
#
# ![](Learning.png)
#
# # SuperVise Learning
# ## 1- Regression(decimal point data)
# ## 2- Discrete(M,F,discrete data)
# # UnSuperVise Learning
# ## * - ind from data set

# %% [markdown]
# ##### k-Nearest Neighbors (Knn) algo(find unknown from known) for both regression and classification(Supervision Learning)
# ##### regression -> price predict
# ##### Euclidean ditance

# %%
# Univariate Case

# %%
acc_value = 3

first_living_space_value = dataset.loc[0,"accommodates"]

# %%
np.sqrt((first_living_space_value-acc_value)**2)
# Out:
# 1.0

# %%
temp_df = dataset.copy()

# %%
temp_df
# Out:
#      host_response_rate host_acceptance_rate  host_listings_count  \
# 0                   92%                  91%                   26
# 1                   90%                 100%                    1
# 2                   90%                 100%                    2
# 3                  100%                  NaN                    1
# 4                   92%                  67%                    1
# ...                 ...                  ...                  ...
# 3718               100%                  60%                    1
# 3719               100%                  50%                    1
# 3720               100%                 100%                    2
# 3721                88%                 100%                    1
# 3722                70%                 100%                    1
#
#       accommodates        room_type  bedrooms  bathrooms  beds    price  \
# 0                4  Entire home/apt       1.0        1.0   2.0  $160.00
# ...

# %%
temp_df["Distance"] = temp_df["accommodates"].apply(lambda x : np.sqrt((x - acc_value)**2))

# %%
temp_df["Distance"].unique()
# Out:
# array([ 1.,  3.,  2.,  4.,  0.,  6.,  7.,  5.,  9., 11., 10., 13., 12.,
#         8.])

# %%
temp_df = temp_df[temp_df["Distance"] == 0]

# %%
# shuffling
np.random.seed(3)
shuffle_index = np.random.permutation(temp_df.index)
shuffle_index
# Out:
# array([2901, 1150, 1281, 2997,  631,  710, 1925,  423, 2064, 2825, 1297,
#        2044,  432, 3568, 1022, 2957,  911,  488, 3488, 1574,  124,  108,
#        3722,  151, 3179, 3060,  950, 3219, 1621, 2313, 1124, 3546, 1117,
#         341, 1205, 1336, 3261, 2219,  115, 3128,  383,  799, 1728,  783,
#         280, 1644, 1086,  895,  457, 2011, 2348, 3349, 1801,  481,  963,
#        1667,  228, 2421, 2680, 2700, 3626, 1213, 1042, 2478, 1164,  886,
#         357, 1091, 3437, 2793, 1399,  316, 2483, 1639,  312, 1075,   75,
#         831, 3340, 2409,  302,  891,  625,  146, 2611, 2055,  172,  690,
#         749, 1737,  972, 3328, 2528,  976,  200, 1501, 3229, 2172, 3072,
#        3413, 2257, 1469, 2338, 1748, 1330, 2479,  596, 1288, 2460, 1271,
#        2089, 2399,  934, 1080, 2868,  899,  301, 3169,  626, 1522,  973,
#        2431, 2122, 1311, 1259, 1275, 2166, 3323, 3140, 2729, 3284, 3619,
#         453, 3631,  289, 1823,  459, 3144, 1761, 3098, 1809,  394, 2277,
# ...

# %%
temp_df = temp_df.loc[shuffle_index]

# %%
temp_df
# Out:
#      host_response_rate host_acceptance_rate  host_listings_count  \
# 2901               100%                  90%                    3
# 1150               100%                 100%                    2
# 1281               100%                 100%                    1
# 2997               100%                 100%                    2
# 631                100%                  57%                    1
# ...                 ...                  ...                  ...
# 3555                80%                 100%                    1
# 943                 NaN                  NaN                    1
# 1832                84%                 100%                    4
# 1074               100%                  86%                    1
# 2817                33%                  67%                    1
#
#       accommodates        room_type  bedrooms  bathrooms  beds    price  \
# 2901             3     Private room       1.0        1.0   1.0   $75.00
# ...

# %%
temp_df["Price"] = temp_df["price"].str.strip("$").str.replace(",","").astype(float)

# %%
k = 5 # Neibours # hyper Parameter jk apni mrzi sy nhi lyty
mean_price = temp_df["Price"].head(k).mean()

# %%
mean_price
# Out:
# 135.4

# %%
def predicted_price(new_listing,k = 5):
    new_df = dataset.copy()
    new_df["distance"] = new_df['accommodates'].apply(lambda x : np.sqrt((x - new_listing)**2))
    new_df = new_df[new_df["distance"] == 0]
    np.random.seed(0)
    shuffle_index = np.random.permutation(new_df.index)
    new_df = new_df.loc[shuffle_index]    
    new_df["price"] = new_df["price"].str.strip("$").str.replace(",","").astype(float) 
    neibour = new_df["price"].head(k) 
    mean_price = neibour.mean()
    return mean_price

# %%
predicted_price(3)
# Out:
# 152.4

# %%
predicted_price(4)
# Out:
# 119.0

# %%
predicted_price(7)
# Out:
# 190.2

# %%
predicted_price(10)
# Out:
# 321.6

# %% [markdown]
# ###### Steps to follow in ML
# * - corelation krna hai
# * - feathure selection \n
# * - non ordinal data remove(nomial) \n
# 4 - non numerical ko delete krna hai \n
# 5 - removing missing data \n
# 6 - koi object value nhi hoti sb numeric hoti hai \n
