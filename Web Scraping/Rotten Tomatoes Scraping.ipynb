# %%
import requests
from bs4 import BeautifulSoup

# %%
base_site = "https://editorial.rottentomatoes.com/guide/essential-movies-to-watch-now/2/"
response = requests.get(base_site)
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.ok
# Out:
# True

# %%
html = response.text
html
# Out:
# '<!DOCTYPE html>\n<html lang="en-US" class="hitim">\n<head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">\n    <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n    \n    <meta property=\'og.description\' content="Rotten Tomatoes staff presents 300 essential movies to watch now, whether you\'re a film buff or just starting your journey into cinema!" />\n    <meta name=\'description\' content="Rotten Tomatoes staff presents 300 essential movies to watch now, whether you\'re a film buff or just starting your journey into cinema!" />\n    <meta property=\'og:title\' content="300 Essential Movies To Watch Now" />\n    <meta property=\'og:type\' content="article" />\n    <meta property=\'og:image\' content="https://prd-rteditorial.s3.us-west-2.amazonaws.com/wp-content/uploads/2019/07/13224158/RT_300EssentialMovies_600x314.jpg" />\n    <meta property=\'og:url\' content="https://editorial.rottentomatoes.com/guide/essential-movi
# ...

# %%
soup = BeautifulSoup(html, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html class="hitim" lang="en-US">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="Rotten Tomatoes staff presents 300 essential movies to watch now, whether you're a film buff or just starting your journey into cinema!" property="og.description"/>
# <meta content="Rotten Tomatoes staff presents 300 essential movies to watch now, whether you're a film buff or just starting your journey into cinema!" name="description"/>
# <meta content="300 Essential Movies To Watch Now" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://prd-rteditorial.s3.us-west-2.amazonaws.com/wp-content/uploads/2019/07/13224158/RT_300EssentialMovies_600x314.jpg" property="og:image"/>
# <meta content="https://editorial.rottentomatoes.com/guide/essential-movies-to-watch-now/" property="og:url"/>
# ...

# %%
divs = soup.find_all("div",{"class":"col-sm-18 col-full-xs countdown-item-content"})
divs
# Out:
# [<div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/jurassic_park">Jurassic Park</a> <span class="subtle start-year">(1993)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">92%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#151</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
# ...

# %%
headings = [div.find("h2") for div in divs]
headings
# Out:
# [<h2><a href="https://www.rottentomatoes.com/m/jurassic_park">Jurassic Park</a> <span class="subtle start-year">(1993)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">92%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/1011615-king_kong">King Kong</a> <span class="subtle start-year">(1933)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">99%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/la_confidential">L.A. Confidential</a> <span class="subtle start-year">(1997)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">99%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/lavventura">L'Avventura</a> <span class="subtle start-year">(1960)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">94%</span></h2>,
# ...

# %%
movie_name = [i.find("a").text for i in headings]
movie_name
# Out:
# ['Jurassic Park',
#  'King Kong',
#  'L.A. Confidential',
#  "L'Avventura",
#  'La Bamba',
#  'La dolce vita',
#  'Lady Bird',
#  'The Lady Eve',
#  'Lawrence of Arabia',
#  'Let the Right One In',
#  'Lethal Weapon',
#  'Like Water for Chocolate',
#  'The Lion King',
#  'The Little Mermaid',
#  'Little Shop of Horrors',
#  'Logan',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Lord of the Rings: The Return of the King',
#  'The Lord of the Rings: The Two Towers',
#  'Lost in Translation',
#  'Love & Basketball',
#  'Mad Max: Fury Road',
#  'Malcolm X',
#  'The Maltese Falcon',
#  'The Manchurian Candidate',
#  'The Matrix',
#  'Mean Girls',
#  'Metropolis',
#  'Modern Times',
#  'Monsoon Wedding',
#  'Monty Python and the Holy Grail',
#  'Moonlight',
#  'Mulholland Dr.',
#  'My Left Foot',
#  'My Neighbor Totoro',
#  'Naked',
#  'The Naked Gun',
#  'Nashville',
#  "National Lampoon's Animal House",
#  'Network',
#  'The Night of the Hunter',
# ...

# %%
headings[0].find("span",class_ = "start-year")
# Out:
# <span class="subtle start-year">(1993)</span>

# %%
year = [i.find("span",class_ = "start-year").text.strip("()") for i in headings]
year
# Out:
# ['1993',
#  '1933',
#  '1997',
#  '1960',
#  '1987',
#  '1960',
#  '2017',
#  '1941',
#  '1962',
#  '2008',
#  '1987',
#  '1992',
#  '1994',
#  '1989',
#  '1986',
#  '2017',
#  '2001',
#  '2003',
#  '2002',
#  '2003',
#  '2000',
#  '2015',
#  '1992',
#  '1941',
#  '1962',
#  '1999',
#  '2004',
#  '1927',
#  '1936',
#  '2001',
#  '1975',
#  '2016',
#  '2001',
#  '1989',
#  '1988',
#  '1993',
#  '1988',
#  '1975',
#  '1978',
#  '1976',
#  '1955',
#  '1968',
#  '1984',
#  '2007',
#  '1959',
#  '1999',
#  '2003',
#  '1954',
#  '1975',
#  '1991',
#  '1945',
#  '2006',
#  '1929',
#  '2019',
#  '1928',
#  '1955',
#  '1940',
#  '1993',
#  '1940',
#  '2012',
#  '1992',
#  '1967',
#  '2019',
#  '1986',
#  '1987',
#  '1997',
#  '1960',
#  '1994',
#  '2018',
#  '1980',
#  '1981',
#  '1950',
#  '1954',
#  '1948',
#  '1984',
#  '2000',
#  '1987',
#  '1976',
#  '1953',
#  '1968',
#  '1939',
#  '2004',
#  '1998',
#  '1989',
#  '1983',
#  '1993',
#  '1996',
#  '2004',
#  '1956',
#  '2014',
# ...

# %%
headings[0]
# Out:
# <h2><a href="https://www.rottentomatoes.com/m/jurassic_park/">Jurassic Park</a> <span class="subtle start-year">(1993)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">92%</span></h2>

# %%
headings[0].find("span",class_ = "tMeterScore")
# Out:
# <span class="tMeterScore">92%</span>

# %%
rating = [i.find("span",class_ = "tMeterScore").text for i in headings]
rating
# Out:
# ['92%',
#  '99%',
#  '99%',
#  '94%',
#  '82%',
#  '96%',
#  '99%',
#  '100%',
#  '94%',
#  '98%',
#  '80%',
#  '87%',
#  '93%',
#  '93%',
#  '90%',
#  '94%',
#  '91%',
#  '93%',
#  '95%',
#  '95%',
#  '86%',
#  '97%',
#  '89%',
#  '100%',
#  '97%',
#  '88%',
#  '84%',
#  '97%',
#  '98%',
#  '95%',
#  '97%',
#  '98%',
#  '84%',
#  '98%',
#  '95%',
#  '88%',
#  '88%',
#  '92%',
#  '90%',
#  '92%',
#  '95%',
#  '96%',
#  '95%',
#  '93%',
#  '97%',
#  '83%',
#  '81%',
#  '99%',
#  '93%',
#  '100%',
#  '100%',
#  '95%',
#  '93%',
#  '98%',
#  '98%',
#  '97%',
#  '100%',
#  '90%',
#  '100%',
#  '81%',
#  '98%',
#  '98%',
#  '97%',
#  '73%',
#  '97%',
#  '93%',
#  '96%',
#  '92%',
#  '93%',
#  '94%',
#  '95%',
#  '98%',
#  '98%',
#  '97%',
#  '98%',
#  '79%',
#  '91%',
#  '91%',
#  '97%',
#  '96%',
#  '96%',
#  '87%',
#  '93%',
#  '98%',
#  '81%',
#  '98%',
#  '79%',
#  '84%',
#  '94%',
#  '99%',
#  '82%',
#  '100%',
#  '94%',
#  '86%',
#  '92%',
#  '91%',
#  '85%',
#  '99%',
#  '88%',
# ...

# %%
consensus = [i.find("div",class_ = "info critics-consensus").text.strip("Critics Consensus:") for i in divs]
consensus
# Out:
# ["Jurassic Park is a spectacle of special effects and life-like animatronics, with some of Spielberg's best sequences of sustained awe and sheer terror since Jaws.",
#  "King Kong explores the soul of a monster -- making audiences scream and cry throughout the film -- in large part due to Kong's breakthrough special effects.",
#  'Taut pacing, brilliantly dense writing and Oscar-worthy acting combine to produce a smart, popcorn-friendly thrill ride.',
#  "L'Avventura marks a bewitchingly ambiguous milestone in Antonioni's career -- and European cinema in general.",
#  "Elevated by a perceptive performance by a perfectly cast Lou Diamond Phillips, La Bamba distills its subject's creative energy -- and reflects his music's enduring appeal.",
#  'An epic, breathtakingly stylish cinematic landmark, La Dolce Vita remains riveting in spite of -- or perhaps because of -- its sprawling length.',
# ...

# %%
directors = [i.find("div",class_ = "director").find("a").text for i in divs]

# %%
directors
# Out:
# ['Steven Spielberg',
#  'Ernest B. Schoedsack',
#  'Curtis Hanson',
#  'Michelangelo Antonioni',
#  'Luis Valdez',
#  'Federico Fellini',
#  'Greta Gerwig',
#  'Preston Sturges',
#  'David Lean',
#  'Tomas Alfredson',
#  'Richard Donner',
#  'Alfonso Arau',
#  'Roger Allers',
#  'John Musker',
#  'Frank Oz',
#  'James Mangold',
#  'Peter Jackson',
#  'Peter Jackson',
#  'Peter Jackson',
#  'Sofia Coppola',
#  'Gina Prince-Bythewood',
#  'George Miller',
#  'Spike Lee',
#  'John Huston',
#  'John Frankenheimer',
#  'Lilly Wachowski',
#  'Mark Waters (VIII)',
#  'Fritz Lang',
#  'Charles Chaplin',
#  'Mira Nair',
#  'Terry Gilliam',
#  'Barry Jenkins (III) ',
#  'David Lynch',
#  'Jim Sheridan',
#  'Hayao Miyazaki',
#  'Mike Leigh',
#  'David Zucker',
#  'Robert Altman',
#  'John Landis',
#  'Sidney Lumet',
#  'Charles Laughton',
#  'George A. Romero',
#  'Wes Craven',
#  'Joel Coen',
#  'Alfred Hitchcock',
#  'Roger Michell',
#  'Park Chan-wook',
#  'Elia Kazan',
#  'Milos Forman',
# ...

# %%
links = divs[1].find("div",class_ = "director").find_all("a")
links
# Out:
# [<a class="" href="/celebrity/ernest_b_schoedsack/">Ernest B. Schoedsack</a>,
#  <a class="" href="/celebrity/merian_c_cooper/">Merian C. Cooper</a>]

# %%
name = [i.text for i in links]
name
# Out:
# ['Ernest B. Schoedsack', 'Merian C. Cooper']

# %%
" , ".join(name)
# Out:
# 'Ernest B. Schoedsack , Merian C. Cooper'
