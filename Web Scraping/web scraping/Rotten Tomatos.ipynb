# %%
import requests
from bs4 import BeautifulSoup

# %%
base_site = "https://editorial.rottentomatoes.com/guide/essential-movies-to-watch-now/2/"
response = requests.get(base_site)
response.ok
# Out:
# True

# %%
html = response.text
soup = BeautifulSoup(html,"lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="Rotten Tomatoes staff presents 300 essential movies to watch now, whether you're a film buff or just starting your journey into cinema!" property="og.description"/>
# <meta content="Rotten Tomatoes staff presents 300 essential movies to watch now, whether you're a film buff or just starting your journey into cinema!" name="description"/>
# <meta content="300 Essential Movies To Watch Now" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2019/07/13224158/RT_300EssentialMovies_600x314.jpg" property="og:image"/>
# <meta content="https://editorial.rottentomatoes.com/guide/essential-movies-to-watch-now/" property="og:url"/>
# ...

# %%
divs = soup.find_all("div" , class_ = "col-sm-6 col-full-xs")
divs
# Out:
# [<div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/jurassic_park/">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/ncVwUYHlrcKvu4mwA8Vc9Ol9hyI=/180x270/v1.bTsxMTE2ODg4MDtqOzE4OTU0OzIwNDg7ODAwOzEyMDA" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>,
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/1011615-king_kong/">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/EFFR10VuXakMFr8WTXiPCIGJb6E=/180x240/v1.bTsxMTI5MjkzNTtqOzE4OTQ1OzIwNDg7MjQwMDszMjAw" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>,
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/la_confidential/">
# ...

# %%
headings = [div.find]

# %%
a = "ali"
b = "hashmi"
c = a+b
c
# Out:
# 'alihashmi'
